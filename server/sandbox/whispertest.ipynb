# %%
import torch
from transformers import AutoModelForSpeechSeq2Seq, AutoProcessor, pipeline
from datasets import load_dataset


device = "cuda:0" if torch.cuda.is_available() else "cpu"
torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32

model_id = "openai/whisper-large-v3"

model = AutoModelForSpeechSeq2Seq.from_pretrained(
    model_id, torch_dtype=torch_dtype, low_cpu_mem_usage=True, use_safetensors=True
)
model.to(device)

processor = AutoProcessor.from_pretrained(model_id)

pipe = pipeline(
    "automatic-speech-recognition",
    model=model,
    tokenizer=processor.tokenizer,
    feature_extractor=processor.feature_extractor,
    torch_dtype=torch_dtype,
    device=device,
)

# dataset = load_dataset("distil-whisper/librispeech_long", "clean", split="validation")
# sample = dataset[0]["audio"]

# result = pipe(sample)
# print(result["text"])

# %%
RECORDING = "./recordings"
sample = f"{RECORDING}/test.mp3"

result = pipe(sample, return_timestamps=True)
print(result["chunks"])
# Out:
# /Users/yikim/Desktop/git/VividReview/venv/lib/python3.9/site-packages/transformers/models/whisper/generation_whisper.py:496: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Due to a bug fix in https://github.com/huggingface/transformers/pull/28687 transcription using a multilingual Whisper will default to language detection followed by transcription instead of translation to English.This might be a breaking change for your use case. If you want to instead always translate your audio to English, make sure to pass `language='en'`.
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.43.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# [{'timestamp': (0.0, 3.5), 'text': ' Okay, so welcome to lecture two of CS231N.'}, {'timestamp': (3.5, 5.92), 'text': ' On Tuesday, we, just recall, we sort of gave you'}, {'timestamp': (5.92, 8.24), 'text': ' the big picture view of what is computer vision,'}, {'timestamp': (8.24, 9.82), 'text': ' what is the history, and a little bit'}, {'timestamp': (9.82, 11.24), 'text': ' of the overview of the class.'}, {'timestamp': (11.24, 12.88), 'text': " And today, we're really gonna dive in"}, {'timestamp': (12.88, 14.58), 'text': ' for the first time into the details,'}, {'timestamp': (14.58, 16.64), 'text': " and we'll start to see in much more depth"}, {'timestamp': (16.64, 18.92), 'text': ' exactly how some of these learning algorithms'}, {'timestamp': (18.92, 20.98), 'text': ' actually work in practice.'}, {'timestamp': (20.98, 22.24), 'text': ' So the first lecture of the class'}, {'timestamp': (22.24, 25.06), 'text': ' is probably the sort of the largest big picture vision,'}, {'timestamp': (25.06, 27.0), 'text': ' and the majority of the lectures in this class'}, {'timestamp': (27.0, 28.72), 'text': ' will be much more detail-oriented,'}, {'timestamp': (0.0, 1.76), 'text': ' much more focused on the specific mechanics'}, {'timestamp': (1.76, 4.0), 'text': ' of these different algorithms.'}, {'timestamp': (4.0, 5.74), 'text': " So today we'll see our first learning algorithm"}, {'timestamp': (5.74, 7.72), 'text': " and that'll be really exciting, I think."}, {'timestamp': (7.72, 10.12), 'text': ' But before we get to that, I wanted to talk about'}, {'timestamp': (10.12, 11.84), 'text': ' a couple administrative issues.'}, {'timestamp': (11.84, 14.0), 'text': ' One is Piazza.'}, {'timestamp': (14.0, 16.0), 'text': ' So I saw, when I checked yesterday,'}, {'timestamp': (16.0, 19.74), 'text': ' it seemed like we had maybe 500 students signed up on Piazza,'}, {'timestamp': (19.74, 21.24), 'text': ' which means that there are several hundred of you'}, {'timestamp': (21.24, 22.88), 'text': ' who are not yet there.'}, {'timestamp': (22.88, 25.94), 'text': ' So we really want Piazza to be the main source'}, {'timestamp': (25.94, 28.68), 'text': ' of communication between the students and the core staff.'}, {'timestamp': (0.0, 3.12), 'text': " So we've gotten a lot of questions to the staff list"}, {'timestamp': (3.12, 6.98), 'text': ' about project ideas or questions about midterm attendance'}, {'timestamp': (6.98, 8.64), 'text': ' or poster session attendance,'}, {'timestamp': (8.64, 10.14), 'text': ' and any sort of questions like that'}, {'timestamp': (10.14, 11.86), 'text': ' should really go to Piazza.'}, {'timestamp': (11.86, 13.56), 'text': " You'll probably get answers to your questions"}, {'timestamp': (13.56, 15.32), 'text': ' faster on Piazza because all the TAs'}, {'timestamp': (15.32, 17.0), 'text': ' are knowing to check that.'}, {'timestamp': (17.0, 19.56), 'text': " And it's sort of easy for emails to get lost in the shuffle"}, {'timestamp': (19.56, 22.04), 'text': ' if you just send to the course list.'}, {'timestamp': (22.04, 24.74), 'text': " It's also come to my attention that some SCPD students"}, {'timestamp': (24.74, 28.2), 'text': ' are having a bit of a hard time signing up for Piazza.'}, {'timestamp': (0.0, 3.08), 'text': ' If you, SCPD students are supposed to receive'}, {'timestamp': (3.08, 6.32), 'text': ' a dot Stanford, at stanford.edu email address.'}, {'timestamp': (6.32, 8.28), 'text': ' So once you get that email address,'}, {'timestamp': (8.28, 11.7), 'text': ' then you can use the Stanford email to sign into Piazza.'}, {'timestamp': (11.7, 13.3), 'text': " Probably that doesn't affect those of you"}, {'timestamp': (13.3, 14.48), 'text': ' who are sitting in the room right now,'}, {'timestamp': (14.48, 17.04), 'text': ' but for those students listening on SCPD.'}, {'timestamp': (19.72, 23.14), 'text': ' The next administrative issue is about assignment one.'}, {'timestamp': (23.14, 25.7), 'text':  ...
